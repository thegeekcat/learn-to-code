# %% [markdown]
# # 1. Preparation

# %%
# Import modules
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# # 2. Color Correction

# %%
# Load images
file_path = './data/bird1.png'
image = cv2.imread(file_path)

# Convert BGR to RGB
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Set parameters
gamma = 5.95
alpha = 1.5  # Contrast control
beta = 5   # Brightness control

# Correct color
#img_corrected = cv2.pow(image/255.0, gamma)
#img_corrected = img_corrected * 255.0
#adjusted = cv2.convertScaleAbs(img_corrected, alpha=alpha, beta=beta)
adjusted = cv2.convertScaleAbs(image, alpha=alpha, beta=beta)

# Visualization
plt.imshow(image)
plt.title('Original Image')
plt.show()

#plt.imshow(img_corrected)
plt.imshow(adjusted)
plt.title('Image after Color Correction')
plt.show()
