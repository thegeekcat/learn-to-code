# %% [markdown]
# # 1. Pearson Correlation Analysis

# %%
# Import modules
import seaborn as sns

# %%
# Load dataset
tips = sns.load_dataset('tips')

tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# Calculate Pearson Correlation Coefficient
corr = tips['total_bill'].corr(tips['tip'], method='pearson')

print('Pearson Correlation Coefficient: ', corr)
# Out:
# Pearson Correlation Coefficient:  0.6757341092113645

# %% [markdown]
# # 2. Covariance

# %% [markdown]
# - Covariance
#    : Use the Pearson Correlation Coefficient, which is a standardized correlation coefficinet, to determine the strength of the correlation between two variables

# %%
# Import modules
import numpy as np
import seaborn as sns

# %%
# Generate data
x = [1, 2, 3, 4, 5]
y = [3, 6, 9, 12, 15]

# Check Covariance
cov_matrix = np.cov(x, y)

cov_matrix
# Out:
# array([[ 2.5,  7.5],
#        [ 7.5, 22.5]])

# %%
# Excercise 2

# Load data
data = sns.load_dataset('tips')

# Calculate Covariance: `pd.cov()`
covariance = tips['total_bill'].cov(tips['tip'])
print('Covariance between "total_bill" and "tip": ', covariance)
# Out:
# Covariance between "total_bill" and "tip":  8.323501629224854

# %% [markdown]
# # 3. Scatter Plot

# %% [markdown]
# - Scatter Plot: Determine relationships between variables
#   - x: Independent variable
#   - y: Dependent variable
# - Scatter Plot Matrix: Determine relationships among multiple variables

# %% [markdown]
# ## 3.1. Basics

# %%
# Import modules
import seaborn as sns

# %%
# Load dataset
tips = sns.load_dataset('tips')

tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# Create a scatter plot
sns.scatterplot(x='total_bill', y='tip', data=tips)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# ## 3.2. Regression Line: `sns.regplot()`

# %% [markdown]
# - Regression Line
#   : A linear function used to express a relationship between two variables on a scatterplot

# %%
# Import modules
import seaborn as sns

# %%
# Load dataset
tips = sns.load_dataset('tips')

tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# Create a scatter plot with a regression line
scatterplot = sns.regplot(x='total_bill', y='tip', data=tips)
scatterplot.set_title("Scatter Plot with a Regression Line")
# Out:
# Text(0.5, 1.0, 'Scatter Plot with a Regression Line')

# %% [markdown]
# # 4. Linear and Non-Linear Relationship

# %%
# Import modules
import numpy as np
import matplotlib.pyplot as plt

# %%
# Generate a linear relationship
x_linear = np.linspace(0, 10, 100)
y_linear = 2 * x_linear + 1

print('X Linear: ', x_linear)
print('\nY Linear: ', y_linear)
# Out:
# X Linear:  [ 0.          0.1010101   0.2020202   0.3030303   0.4040404   0.50505051
#   0.60606061  0.70707071  0.80808081  0.90909091  1.01010101  1.11111111
#   1.21212121  1.31313131  1.41414141  1.51515152  1.61616162  1.71717172
#   1.81818182  1.91919192  2.02020202  2.12121212  2.22222222  2.32323232
#   2.42424242  2.52525253  2.62626263  2.72727273  2.82828283  2.92929293
#   3.03030303  3.13131313  3.23232323  3.33333333  3.43434343  3.53535354
#   3.63636364  3.73737374  3.83838384  3.93939394  4.04040404  4.14141414
#   4.24242424  4.34343434  4.44444444  4.54545455  4.64646465  4.74747475
#   4.84848485  4.94949495  5.05050505  5.15151515  5.25252525  5.35353535
#   5.45454545  5.55555556  5.65656566  5.75757576  5.85858586  5.95959596
#   6.06060606  6.16161616  6.26262626  6.36363636  6.46464646  6.56565657
#   6.66666667  6.76767677  6.86868687  6.96969697  7.07070707  7.17171717
#   7.27272727  7.37373737  7.47474747  7.57575758  7.67676768  7.77777778
# ...

# %%
# Generate a Non-Linear Relationship
x_nonlinear = np.linspace(-10, 10, 100)
y_nonlinear = x_nonlinear ** 2

print('X Non-Linear: ', x_nonlinear)
print('\nY Non-Linear: ', y_nonlinear)
# Out:
# X Non-Linear:  [-10.          -9.7979798   -9.5959596   -9.39393939  -9.19191919
#   -8.98989899  -8.78787879  -8.58585859  -8.38383838  -8.18181818
#   -7.97979798  -7.77777778  -7.57575758  -7.37373737  -7.17171717
#   -6.96969697  -6.76767677  -6.56565657  -6.36363636  -6.16161616
#   -5.95959596  -5.75757576  -5.55555556  -5.35353535  -5.15151515
#   -4.94949495  -4.74747475  -4.54545455  -4.34343434  -4.14141414
#   -3.93939394  -3.73737374  -3.53535354  -3.33333333  -3.13131313
#   -2.92929293  -2.72727273  -2.52525253  -2.32323232  -2.12121212
#   -1.91919192  -1.71717172  -1.51515152  -1.31313131  -1.11111111
#   -0.90909091  -0.70707071  -0.50505051  -0.3030303   -0.1010101
#    0.1010101    0.3030303    0.50505051   0.70707071   0.90909091
#    1.11111111   1.31313131   1.51515152   1.71717172   1.91919192
#    2.12121212   2.32323232   2.52525253   2.72727273   2.92929293
#    3.13131313   3.33333333   3.53535354   3.73737374   3.93939394
# ...

# %%
# 선형 관계 시각화
plt.scatter(x_linear, y_linear)
plt.title('Linear Relationship')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

# 비선형 관계 시각화
plt.scatter(x_nonlinear, y_nonlinear)
plt.title('Nonlinear Relationship')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

# %% [markdown]
# # 5. Multiple Correlation Analysis

# %% [markdown]
# - Multiple Correlation Analysis
#   : A method of analyzing correlation between two or more independent variables and one dependent variable.

# %%
# Import modules 
import seaborn as sns

# %%
# Load dataset
cols = ['survived', 'pclass', 'age', 'fare']

df = sns.load_dataset('titanic')[cols].dropna()

df
# Out:
#      survived  pclass   age     fare
# 0           0       3  22.0   7.2500
# 1           1       1  38.0  71.2833
# 2           1       3  26.0   7.9250
# 3           1       1  35.0  53.1000
# 4           0       3  35.0   8.0500
# ..        ...     ...   ...      ...
# 885         0       3  39.0  29.1250
# 886         0       2  27.0  13.0000
# 887         1       1  19.0  30.0000
# 889         1       1  26.0  30.0000
# 890         0       3  32.0   7.7500
#
# [714 rows x 4 columns]

# %%
corr = df.corr()

corr
# Out:
#           survived    pclass       age      fare
# survived  1.000000 -0.359653 -0.077221  0.268189
# pclass   -0.359653  1.000000 -0.369226 -0.554182
# age      -0.077221 -0.369226  1.000000  0.096067
# fare      0.268189 -0.554182  0.096067  1.000000

# %% [markdown]
# # 6. Time Series Correlation Analysis

# %%
# Import modules
import pandas as pd
import random
import os
import matplotlib.pyplot as plt

# %%
# Generate data: 'dates'
dates = pd.date_range(start='2021-01-04',
                       periods = 100,  # Numbers of data
                       freq = 'D')

dates
# Out:
# DatetimeIndex(['2021-01-04', '2021-01-05', '2021-01-06', '2021-01-07',
#                '2021-01-08', '2021-01-09', '2021-01-10', '2021-01-11',
#                '2021-01-12', '2021-01-13', '2021-01-14', '2021-01-15',
#                '2021-01-16', '2021-01-17', '2021-01-18', '2021-01-19',
#                '2021-01-20', '2021-01-21', '2021-01-22', '2021-01-23',
#                '2021-01-24', '2021-01-25', '2021-01-26', '2021-01-27',
#                '2021-01-28', '2021-01-29', '2021-01-30', '2021-01-31',
#                '2021-02-01', '2021-02-02', '2021-02-03', '2021-02-04',
#                '2021-02-05', '2021-02-06', '2021-02-07', '2021-02-08',
#                '2021-02-09', '2021-02-10', '2021-02-11', '2021-02-12',
#                '2021-02-13', '2021-02-14', '2021-02-15', '2021-02-16',
#                '2021-02-17', '2021-02-18', '2021-02-19', '2021-02-20',
#                '2021-02-21', '2021-02-22', '2021-02-23', '2021-02-24',
# ...

# %%
# Generate data: `Samsung`
samsung_prices = [random.randint(80000, 90000) for _ in range(100)]
samsung_data = {'Date': dates,
               '005930.KS': samsung_prices}
samsung_df = pd.DataFrame(samsung_data)

samsung_df
# Out:
#          Date  005930.KS
# 0  2021-01-04      85438
# 1  2021-01-05      83923
# 2  2021-01-06      85562
# 3  2021-01-07      88905
# 4  2021-01-08      84440
# ..        ...        ...
# 95 2021-04-09      80339
# 96 2021-04-10      82265
# 97 2021-04-11      82781
# 98 2021-04-12      85865
# 99 2021-04-13      82909
#
# [100 rows x 2 columns]

# %%
# Clean `Samsung` data: Remove Indexes
samsung_df.set_index('Date', inplace=True)  # Replace 'Date' as an Index column

samsung_df
# Out:
#             005930.KS
# Date
# 2021-01-04      85438
# 2021-01-05      83923
# 2021-01-06      85562
# 2021-01-07      88905
# 2021-01-08      84440
# ...               ...
# 2021-04-09      80339
# 2021-04-10      82265
# 2021-04-11      82781
# 2021-04-12      85865
# 2021-04-13      82909
#
# [100 rows x 1 columns]

# %%
# Generate data: `LG`
lg_prices = [random.randint(140000, 160000) for _ in range(100)]
lg_data = {'Date': dates, '066570.KS': lg_prices}
lg_df = pd.DataFrame(lg_data)

lg_df
# Out:
#          Date  066570.KS
# 0  2021-01-04     149297
# 1  2021-01-05     148419
# 2  2021-01-06     156874
# 3  2021-01-07     141040
# 4  2021-01-08     146229
# ..        ...        ...
# 95 2021-04-09     154220
# 96 2021-04-10     150667
# 97 2021-04-11     157513
# 98 2021-04-12     155816
# 99 2021-04-13     142384
#
# [100 rows x 2 columns]

# %%
# Clean 'LG' data: Remove Indexes
lg_df.set_index('Date', inplace=True)

lg_df
# Out:
#             066570.KS
# Date
# 2021-01-04     149297
# 2021-01-05     148419
# 2021-01-06     156874
# 2021-01-07     141040
# 2021-01-08     146229
# ...               ...
# 2021-04-09     154220
# 2021-04-10     150667
# 2021-04-11     157513
# 2021-04-12     155816
# 2021-04-13     142384
#
# [100 rows x 1 columns]

# %%
# Combine two dataframes: `pd.concat()`
df = pd.concat([samsung_df, lg_df], axis=1)

df
# Out:
#             005930.KS  066570.KS
# Date
# 2021-01-04      85438     149297
# 2021-01-05      83923     148419
# 2021-01-06      85562     156874
# 2021-01-07      88905     141040
# 2021-01-08      84440     146229
# ...               ...        ...
# 2021-04-09      80339     154220
# 2021-04-10      82265     150667
# 2021-04-11      82781     157513
# 2021-04-12      85865     155816
# 2021-04-13      82909     142384
#
# [100 rows x 2 columns]

# %%
# Rename columns
df = df.loc[:, ['005930.KS', '066570.KS']]

df.columns = ['Samsung', 'LG']

df
# Out:
#             Samsung      LG
# Date
# 2021-01-04    85438  149297
# 2021-01-05    83923  148419
# 2021-01-06    85562  156874
# 2021-01-07    88905  141040
# 2021-01-08    84440  146229
# ...             ...     ...
# 2021-04-09    80339  154220
# 2021-04-10    82265  150667
# 2021-04-11    82781  157513
# 2021-04-12    85865  155816
# 2021-04-13    82909  142384
#
# [100 rows x 2 columns]

# %%
# Create a folder
os.makedirs("./data", exist_ok=True)

# Save as a new file
df.to_csv("./data/stock_price.csv")

# %%
# Load the file
df = pd.read_csv('./data/stock_price.csv')

df
# Out:
#           Date  Samsung      LG
# 0   2021-01-04    85438  149297
# 1   2021-01-05    83923  148419
# 2   2021-01-06    85562  156874
# 3   2021-01-07    88905  141040
# 4   2021-01-08    84440  146229
# ..         ...      ...     ...
# 95  2021-04-09    80339  154220
# 96  2021-04-10    82265  150667
# 97  2021-04-11    82781  157513
# 98  2021-04-12    85865  155816
# 99  2021-04-13    82909  142384
#
# [100 rows x 3 columns]

# %%
# Change 'Date' column to 'datetime' type
df['Date'] = pd.to_datetime(df['Date'])

# Replace 'Date' as an Index
df.set_index('Date', inplace=True)

df
# Out:
#             Samsung      LG
# Date
# 2021-01-04    85438  149297
# 2021-01-05    83923  148419
# 2021-01-06    85562  156874
# 2021-01-07    88905  141040
# 2021-01-08    84440  146229
# ...             ...     ...
# 2021-04-09    80339  154220
# 2021-04-10    82265  150667
# 2021-04-11    82781  157513
# 2021-04-12    85865  155816
# 2021-04-13    82909  142384
#
# [100 rows x 2 columns]

# %%
# Calculate returns: `df.pct_change()`
returns = df.pct_change()  

returns
# Out:
#              Samsung        LG
# Date
# 2021-01-04       NaN       NaN
# 2021-01-05 -0.017732 -0.005881
# 2021-01-06  0.019530  0.056967
# 2021-01-07  0.039071 -0.100935
# 2021-01-08 -0.050222  0.036791
# ...              ...       ...
# 2021-04-09 -0.082605  0.066071
# 2021-04-10  0.023973 -0.023039
# 2021-04-11  0.006272  0.045438
# 2021-04-12  0.037255 -0.010774
# 2021-04-13 -0.034426 -0.086204
#
# [100 rows x 2 columns]

# %%
# Calculate the Correlation Coefficient between returns
corr_matrix = returns.corr()

corr_matrix
# Out:
#           Samsung        LG
# Samsung  1.000000 -0.195967
# LG      -0.195967  1.000000

# %%
# Visualization: Heapmap
sns.heatmap(corr_matrix, 
           annot = True,
           cmap = 'coolwarm')

plt.show()

# %% [markdown]
# # Excercise

# %% [markdown]
# # 1. Generate Data

# %%
# Import modules
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Generate data

np.random.seed(0)

grade_range = [np.random.randint(1, 4) for _ in range(300)]
grade_df = pd.DataFrame(grade_range, columns=["Grade"])
#grade_df

score_range = np.random.randint(0, 100, size=(300, 3))
score_df = pd.DataFrame(score_range, columns=["Math", "English", "Korean"])
#score_df

student_df = pd.concat([grade_df, score_df], axis=1)
#student_df.set_index('Grade', inplace=True)
student_df
# Out:
#      Grade  Math  English  Korean
# 0        1    91       73      28
# 1        2    81       58       0
# 2        1    86       63      16
# 3        2    36       94      24
# 4        2    63       67      51
# ..     ...   ...      ...     ...
# 295      2    20       38      64
# 296      2     6       22      79
# 297      2    74       34      40
# 298      3    38       21      34
# 299      1    32       42      44
#
# [300 rows x 4 columns]

# %% [markdown]
# # 2. Export as a `csv` file

# %%
# Create a folder
os.makedirs("./data", exist_ok=True)

# Save as a new file
student_df.to_csv("./data/student_scores.csv")

# %% [markdown]
# # 3. Visualization: Heatmap

# %%
# Calculate returns: `df.pct_change()`
returns = student_df.pct_change()  
    
returns
# Out:
#         Grade       Math   English    Korean
# 0         NaN        NaN       NaN       NaN
# 1    1.000000  -0.109890 -0.205479 -1.000000
# 2   -0.500000   0.061728  0.086207       inf
# 3    1.000000  -0.581395  0.492063  0.500000
# 4    0.000000   0.750000 -0.287234  1.125000
# ..        ...        ...       ...       ...
# 295 -0.333333  -0.696970 -0.191489  2.764706
# 296  0.000000  -0.700000 -0.421053  0.234375
# 297  0.000000  11.333333  0.545455 -0.493671
# 298  0.500000  -0.486486 -0.382353 -0.150000
# 299 -0.666667  -0.157895  1.000000  0.294118
#
# [300 rows x 4 columns]

# %%
# Calculate Correlation
corr_matrix = returns.corr()

corr_matrix
# Out:
#             Grade      Math   English    Korean
# Grade    1.000000 -0.058349  0.082372 -0.011219
# Math    -0.058349  1.000000 -0.031613 -0.016814
# English  0.082372 -0.031613  1.000000  0.033486
# Korean  -0.011219 -0.016814  0.033486  1.000000

# %%
# Visualization: Heapmap
sns.heatmap(corr_matrix, 
           annot = True,
           cmap = 'coolwarm')

plt.show()

# %% [markdown]
# # 4. Look at DataFrame

# %%
# Get info of scores
print('Math: \n', student_df["Math"].describe())
print('\n\nEnglish: \n', student_df["English"].describe())
print('\n\nKorean: \n', student_df["Korean"].describe())
# Out:
# Math:
#  count    300.000000
# mean      49.240000
# std       29.409729
# min        0.000000
# 25%       23.750000
# 50%       49.500000
# 75%       78.000000
# max       99.000000
# Name: Math, dtype: float64
#
#
# English:
#  count    300.000000
# mean      48.530000
# std       29.909939
# min        0.000000
# 25%       22.000000
# 50%       47.000000
# 75%       74.500000
# max       99.000000
# Name: English, dtype: float64
#
#
# Korean:
#  count    300.000000
# mean      51.133333
# std       29.742072
# min        0.000000
# 25%       26.000000
# 50%       53.000000
# 75%       78.000000
# max       99.000000
# Name: Korean, dtype: float64

# %% [markdown]
# # 5. Visualization: Histogram

# %%
# Visualization: Math
plt.hist(student_df['Math'], bins=10)
plt.xlabel('Score: Math')
plt.ylabel('Number of Students')
plt.title('Math Scores Distribution')
plt.show()

# Visualization: English
plt.hist(student_df['English'], bins=10)
plt.xlabel('Score: English')
plt.ylabel('Number of Students')
plt.title('English Scores Distribution')
plt.show()

# Visualization: Korean
plt.hist(student_df['Korean'], bins=10)
plt.xlabel('Score: Korean')
plt.ylabel('Number of Students')
plt.title('Korean Scores Distribution')
plt.show()
