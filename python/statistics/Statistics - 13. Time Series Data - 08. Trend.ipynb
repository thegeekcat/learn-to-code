# %% [markdown]
# # 8. Trend

# %% [markdown]
# ### Preparation

# %%
# Import modules
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from statsmodels.tsa.seasonal import seasonal_decompose  # Decompose periodical data to return Trends, Seasonality, Residuals

# %%
# Generate data
np.random.seed(85)

date = pd.date_range(start='2023-01-01', periods=100, freq='D')
values = [3, 15, 14, 21, 15, 32, 15, 43, 10, 32] * 10

date, values
# Out:
# (DatetimeIndex(['2023-01-01', '2023-01-02', '2023-01-03', '2023-01-04',
#                 '2023-01-05', '2023-01-06', '2023-01-07', '2023-01-08',
#                 '2023-01-09', '2023-01-10', '2023-01-11', '2023-01-12',
#                 '2023-01-13', '2023-01-14', '2023-01-15', '2023-01-16',
#                 '2023-01-17', '2023-01-18', '2023-01-19', '2023-01-20',
#                 '2023-01-21', '2023-01-22', '2023-01-23', '2023-01-24',
#                 '2023-01-25', '2023-01-26', '2023-01-27', '2023-01-28',
#                 '2023-01-29', '2023-01-30', '2023-01-31', '2023-02-01',
#                 '2023-02-02', '2023-02-03', '2023-02-04', '2023-02-05',
#                 '2023-02-06', '2023-02-07', '2023-02-08', '2023-02-09',
#                 '2023-02-10', '2023-02-11', '2023-02-12', '2023-02-13',
#                 '2023-02-14', '2023-02-15', '2023-02-16', '2023-02-17',
#                 '2023-02-18', '2023-02-19', '2023-02-20', '2023-02-21',
# ...

# %%
# Create a dataframe
data = pd.DataFrame({
    'Date': date,
    'Values': values
})

data
# Out:
#          Date  Values
# 0  2023-01-01       3
# 1  2023-01-02      15
# 2  2023-01-03      14
# 3  2023-01-04      21
# 4  2023-01-05      15
# ..        ...     ...
# 95 2023-04-06      32
# 96 2023-04-07      15
# 97 2023-04-08      43
# 98 2023-04-09      10
# 99 2023-04-10      32
#
# [100 rows x 2 columns]

# %% [markdown]
# ### Set and Decompose Periods

# %%
# Set a Period
period = 7   # Data repeating every 7 days

# %%
# Decompose the Period
result = seasonal_decompose(data['Values'], model='additive', period=period)

# %%
# Calculate trends
trend = result.trend

trend
# Out:
# 0           NaN
# 1           NaN
# 2           NaN
# 3     16.428571
# 4     22.142857
#         ...
# 95    21.428571
# 96    24.000000
# 97          NaN
# 98          NaN
# 99          NaN
# Name: trend, Length: 100, dtype: float64

# %% [markdown]
# ### Visualization

# %%
# Visualization
plt.plot(data['Date'], data['Values'], label='Original')
plt.plot(data['Date'], trend, label='Trend')

plt.xlabel('Date')
plt.ylabel('Values')
plt.title('Trend Extraction in Time Series Data')
plt.legend()
plt.xticks(rotation=45)

plt.show()
