# %% [markdown]
# # 3. Visualization for Trends: Upward, Downward, Flat Trends

# %% [markdown]
# ## 3.1. Preparation

# %%
# Import modules
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Generate data
np.random.seed(85)

dates = pd.date_range(start='2023-01-01', periods=100, freq='D')
values = np.random.randn(100).cumsum() #np.cumsum(): Cululative Summation

dates, values
# Out:
# (DatetimeIndex(['2023-01-01', '2023-01-02', '2023-01-03', '2023-01-04',
#                 '2023-01-05', '2023-01-06', '2023-01-07', '2023-01-08',
#                 '2023-01-09', '2023-01-10', '2023-01-11', '2023-01-12',
#                 '2023-01-13', '2023-01-14', '2023-01-15', '2023-01-16',
#                 '2023-01-17', '2023-01-18', '2023-01-19', '2023-01-20',
#                 '2023-01-21', '2023-01-22', '2023-01-23', '2023-01-24',
#                 '2023-01-25', '2023-01-26', '2023-01-27', '2023-01-28',
#                 '2023-01-29', '2023-01-30', '2023-01-31', '2023-02-01',
#                 '2023-02-02', '2023-02-03', '2023-02-04', '2023-02-05',
#                 '2023-02-06', '2023-02-07', '2023-02-08', '2023-02-09',
#                 '2023-02-10', '2023-02-11', '2023-02-12', '2023-02-13',
#                 '2023-02-14', '2023-02-15', '2023-02-16', '2023-02-17',
#                 '2023-02-18', '2023-02-19', '2023-02-20', '2023-02-21',
#                 '2023-02-22', '2023-02-23', '2023-02-24', '2023-02-25',
#                 '2023-02-26', '2023-02-27', '2023-02-28', '2023-03-01',
#                 '2023-03-02', '2023-03-03', '2023-03-04', '2023-03-05',
#                 '2023-03-06', '2023-03-07', '2023-03-08', '2023-03-09',
#                 '2023-03-10', '2023-03-11', '2023-03-12', '2023-03-13',
#                 '2023-03-14', '2023-03-15', '2023-03-16', '2023-03-17',
#                 '2023-03-18', '2023-03-19', '2023-03-20', '2023-03-21',
#                 '2023-03-22', '2023-03-23', '2023-03-24', '2023-03-25',
#                 '2023-03-26', '2023-03-27', '2023-03-28', '2023-03-29',
#                 '2023-03-30', '2023-03-31', '2023-04-01', '2023-04-02',
#                 '2023-04-03', '2023-04-04', '2023-04-05', '2023-04-06',
#                 '2023-04-07', '2023-04-08', '2023-04-09', '2023-04-10'],
#                dtype='datetime64[ns]', freq='D'),
#  array([ 0.17685072,  2.55460485,  3.5533377 ,  2.24318691,  2.42337683,
#          0.65862281, -0.78450306, -2.18378862, -1.36343462, -0.0681353 ,
#          0.87406212,  0.64212983,  0.01073187, -0.63144516, -1.01311676,
#         -2.77656076, -1.16489255, -2.04300094, -2.541578  , -1.6343346 ,
#         -1.59300518,  0.22246956, -0.90767139, -1.38001839, -1.87750928,
#         -1.8385725 , -0.46237777,  0.02905459,  0.61596548, -0.66815086,
#          1.11175945, -0.1772389 , -0.9609818 , -2.01991938, -2.42715813,
#         -2.66946288, -1.5623396 , -1.48943898, -2.90194578, -3.30720576,
#         -4.80129248, -3.82142189, -3.40958161, -2.654079  , -2.48948991,
#         -2.41758174, -2.29836355, -1.28430566, -2.28383074, -1.69263024,
#         -2.70218717, -2.39739396, -3.678111  , -4.25524852, -4.0810313 ,
#         -2.59007652, -3.25894287, -3.4672395 , -4.46257765, -4.36501283,
#         -5.96063751, -4.30317097, -2.41651191, -1.78792928, -1.41238162,
#         -1.48444287, -0.6386622 , -0.99352394, -1.06065349, -1.76312676,
#         -2.25050887, -1.26575104, -0.6160457 ,  1.09853621,  1.89355369,
#          1.12105284,  3.15686467,  2.11174194,  0.64998438, -0.38399635,
#         -1.01378641, -1.89460618, -2.2955307 , -0.90728058, -2.36703376,
#         -2.95307738, -0.86674832, -2.48378058, -3.43764738, -3.17583456,
#         -3.27422332, -3.09693617, -4.45138574, -4.1814202 , -5.45901868,
#         -6.78260428, -6.54467117, -7.29893762, -8.56811112, -7.44867969]))

# %%
# Create a dataframe
data = pd.DataFrame({
    'Date': dates,
    'Values': values
})

data
# Out:
#          Date    Values
# 0  2023-01-01  0.176851
# 1  2023-01-02  2.554605
# 2  2023-01-03  3.553338
# 3  2023-01-04  2.243187
# 4  2023-01-05  2.423377
# ..        ...       ...
# 95 2023-04-06 -6.782604
# 96 2023-04-07 -6.544671
# 97 2023-04-08 -7.298938
# 98 2023-04-09 -8.568111
# 99 2023-04-10 -7.448680
#
# [100 rows x 2 columns]

# %% [markdown]
# ## 3.2. Upward Trends

# %%
# Generate data for upward trend
data['Upward_Trend'] = np.linspace(0, 50, len(data))   # np.linspace(): Generate numbers uniformly from Start to End

data['Upward_Trend']
# Out:
# 0      0.000000
# 1      0.505051
# 2      1.010101
# 3      1.515152
# 4      2.020202
#         ...
# 95    47.979798
# 96    48.484848
# 97    48.989899
# 98    49.494949
# 99    50.000000
# Name: Upward_Trend, Length: 100, dtype: float64

# %%
# Visualization
plt.plot(data['Date'], data['Upward_Trend'], label='Upward Trend')

plt.xlabel('Date')
plt.ylabel('Values')
plt.title('Upward Trends')
plt.legend()
plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# ## 3.3. Downward Trends

# %%
# Generate data
data['Downward_Trend'] = np.linspace(50, 0, len(data))

data['Downward_Trend']
# Out:
# 0     50.000000
# 1     49.494949
# 2     48.989899
# 3     48.484848
# 4     47.979798
#         ...
# 95     2.020202
# 96     1.515152
# 97     1.010101
# 98     0.505051
# 99     0.000000
# Name: Downward_Trend, Length: 100, dtype: float64

# %%
# Visualization
plt.plot(data['Date'], data['Downward_Trend'], label='Downward Trend')

plt.xlabel('Date')
plt.ylabel('Values')
plt.title('Downward Trends')
plt.legend()
plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# ## 3.4. Flat Trend

# %%
# Generate data
data['Flat_Trend'] = np.full(len(data), 50)

data['Flat_Trend']
# Out:
# 0     50
# 1     50
# 2     50
# 3     50
# 4     50
#       ..
# 95    50
# 96    50
# 97    50
# 98    50
# 99    50
# Name: Flat_Trend, Length: 100, dtype: int32

# %%
# Visualization
plt.plot(data['Date'], data['Flat_Trend'], label='Flat Trend')

plt.xlabel('Date')
plt.ylabel('Values')
plt.title('Flat Trends')
plt.legend()
plt.xticks(rotation=45)

plt.show()
