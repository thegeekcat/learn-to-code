# %%
# Install Albumentations
# !pip install albumentations
# Out:
# Requirement already satisfied: albumentations in c:\users\genih\appdata\roaming\python\python38\site-packages (1.3.1)
# Requirement already satisfied: numpy>=1.11.1 in c:\users\genih\appdata\roaming\python\python38\site-packages (from albumentations) (1.24.3)
# Requirement already satisfied: opencv-python-headless>=4.1.1 in c:\users\genih\appdata\roaming\python\python38\site-packages (from albumentations) (4.7.0.72)
# Requirement already satisfied: PyYAML in c:\mine\programming\anaconda3\envs\ai\lib\site-packages (from albumentations) (6.0)
# Requirement already satisfied: scipy>=1.1.0 in c:\users\genih\appdata\roaming\python\python38\site-packages (from albumentations) (1.10.1)
# Requirement already satisfied: qudida>=0.0.4 in c:\users\genih\appdata\roaming\python\python38\site-packages (from albumentations) (0.0.4)
# Requirement already satisfied: scikit-image>=0.16.1 in c:\users\genih\appdata\roaming\python\python38\site-packages (from albumentations) (0.21.0)
# Requirement already satisfied: typing-extensions in c:\mine\programming\anaconda3\envs\ai\lib\site-packages (from qudida>=0.0.4->albumentations) (4.5.0)
# Requirement already satisfied: scikit-learn>=0.19.1 in c:\users\genih\appdata\roaming\python\python38\site-packages (from qudida>=0.0.4->albumentations) (1.2.2)
# Requirement already satisfied: tifffile>=2022.8.12 in c:\users\genih\appdata\roaming\python\python38\site-packages (from scikit-image>=0.16.1->albumentations) (2023.4.12)
# Requirement already satisfied: imageio>=2.27 in c:\users\genih\appdata\roaming\python\python38\site-packages (from scikit-image>=0.16.1->albumentations) (2.31.1)
# Requirement already satisfied: lazy_loader>=0.2 in c:\users\genih\appdata\roaming\python\python38\site-packages (from scikit-image>=0.16.1->albumentations) (0.2)
# Requirement already satisfied: packaging>=21 in c:\mine\programming\anaconda3\envs\ai\lib\site-packages (from scikit-image>=0.16.1->albumentations) (23.1)
# Requirement already satisfied: PyWavelets>=1.1.1 in c:\users\genih\appdata\roaming\python\python38\site-packages (from scikit-image>=0.16.1->albumentations) (1.4.1)
# Requirement already satisfied: pillow>=9.0.1 in c:\users\genih\appdata\roaming\python\python38\site-packages (from scikit-image>=0.16.1->albumentations) (9.5.0)
# Requirement already satisfied: networkx>=2.8 in c:\users\genih\appdata\roaming\python\python38\site-packages (from scikit-image>=0.16.1->albumentations) (3.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\genih\appdata\roaming\python\python38\site-packages (from scikit-learn>=0.19.1->qudida>=0.0.4->albumentations) (3.1.0)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\genih\appdata\roaming\python\python38\site-packages (from scikit-learn>=0.19.1->qudida>=0.0.4->albumentations) (1.2.0)

# %% [markdown]
# # 1. Preparation

# %%
# Import modules
import random
import cv2
import albumentations as A
from matplotlib import pyplot as plt

# %%
# Define a function for visualization
def visualization(image, name):
    plt.figure(figsize=(10, 10))
    plt.axis('off') # An option to display axises
    plt.title(name)
    plt.imshow(image)

# Load images
image = cv2.imread('./data/cat_dog_rabbit.PNG')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Visualization
visualization(image, 'Original Image')

# %% [markdown]
# # 2. Horizontal Flip

# %%
# Horizontal Flip
transform = A.HorizontalFlip(p=0.5)  # 'p=0.5': 50% chance to apply horizontal flip transformation
random.seed(85)
image_adjusted = transform(image = image)['image']

# Visualization
visualization(image, 'Original Image')
visualization(image_adjusted, 'Adjusted Image: Horizontal Flip')

# %% [markdown]
# # 3. Shift Scale Rotation

# %%
# Shift Scale Rotation
transform = A.ShiftScaleRotate(p = 0.5)
random.seed(85)
image_adjusted = transform(image = image)['image']

# Visualization
visualization(image, 'Original Image')
visualization(image_adjusted, 'Adjusted Image: Shift Scale Rotation')

# %% [markdown]
# # 4. A Multiple Transformation Pipeline

# %%
# Create a multiple transformation pipeline
transform = A.Compose([  # 'Compose()': Combine multiple transformations into a single transformation pipeline
    A.CLAHE(),  # CLAHE(Applies Contrast Limited Adaptive Histogram Equalization): Enhance image contrast
    A.RandomRotate90(),
    A.Transpose(), # Swap rows and columns
    A.ShiftScaleRotate(shift_limit=0.0625, scale_limit=0.50, rotate_limit=45, p=0.75),
    A.Blur(blur_limit=3),
    A.OpticalDistortion(),
    A.GridDistortion(),
    A.HueSaturationValue()
])
#random.seed(85)
image_adjusted = transform(image = image)['image']

# Visualization
visualization(image, 'Original Image')
visualization(image_adjusted, 'Adjusted Image: Multiple Transformation applied')

# %% [markdown]
# # 5. A Multiple Transformation Pipeline with random options

# %%
# Install modules
#!pip install imgaug
# !pip install -U albumentations[imgaug]
# Out:
# Requirement already satisfied: albumentations[imgaug] in c:\users\genih\appdata\roaming\python\python38\site-packages (1.3.1)
# Requirement already satisfied: scikit-image>=0.16.1 in c:\users\genih\appdata\roaming\python\python38\site-packages (from albumentations[imgaug]) (0.21.0)
# Requirement already satisfied: qudida>=0.0.4 in c:\users\genih\appdata\roaming\python\python38\site-packages (from albumentations[imgaug]) (0.0.4)
# Requirement already satisfied: opencv-python-headless>=4.1.1 in c:\users\genih\appdata\roaming\python\python38\site-packages (from albumentations[imgaug]) (4.7.0.72)
# Requirement already satisfied: PyYAML in c:\mine\programming\anaconda3\envs\ai\lib\site-packages (from albumentations[imgaug]) (6.0)
# Requirement already satisfied: numpy>=1.11.1 in c:\users\genih\appdata\roaming\python\python38\site-packages (from albumentations[imgaug]) (1.24.3)
# Requirement already satisfied: scipy>=1.1.0 in c:\users\genih\appdata\roaming\python\python38\site-packages (from albumentations[imgaug]) (1.10.1)
# Requirement already satisfied: imgaug>=0.4.0 in c:\mine\programming\anaconda3\envs\ai\lib\site-packages (from albumentations[imgaug]) (0.4.0)
# Requirement already satisfied: six in c:\mine\programming\anaconda3\envs\ai\lib\site-packages (from imgaug>=0.4.0->albumentations[imgaug]) (1.16.0)
# Requirement already satisfied: imageio in c:\users\genih\appdata\roaming\python\python38\site-packages (from imgaug>=0.4.0->albumentations[imgaug]) (2.31.1)
# Requirement already satisfied: opencv-python in c:\users\genih\appdata\roaming\python\python38\site-packages (from imgaug>=0.4.0->albumentations[imgaug]) (4.5.5.64)
# Requirement already satisfied: Pillow in c:\users\genih\appdata\roaming\python\python38\site-packages (from imgaug>=0.4.0->albumentations[imgaug]) (9.5.0)
# Requirement already satisfied: Shapely in c:\users\genih\appdata\roaming\python\python38\site-packages (from imgaug>=0.4.0->albumentations[imgaug]) (2.0.1)
# Requirement already satisfied: matplotlib in c:\users\genih\appdata\roaming\python\python38\site-packages (from imgaug>=0.4.0->albumentations[imgaug]) (3.7.1)
# Requirement already satisfied: scikit-learn>=0.19.1 in c:\users\genih\appdata\roaming\python\python38\site-packages (from qudida>=0.0.4->albumentations[imgaug]) (1.2.2)
# Requirement already satisfied: typing-extensions in c:\mine\programming\anaconda3\envs\ai\lib\site-packages (from qudida>=0.0.4->albumentations[imgaug]) (4.5.0)
# Requirement already satisfied: PyWavelets>=1.1.1 in c:\users\genih\appdata\roaming\python\python38\site-packages (from scikit-image>=0.16.1->albumentations[imgaug]) (1.4.1)
# Requirement already satisfied: networkx>=2.8 in c:\users\genih\appdata\roaming\python\python38\site-packages (from scikit-image>=0.16.1->albumentations[imgaug]) (3.1)
# Requirement already satisfied: tifffile>=2022.8.12 in c:\users\genih\appdata\roaming\python\python38\site-packages (from scikit-image>=0.16.1->albumentations[imgaug]) (2023.4.12)
# Requirement already satisfied: packaging>=21 in c:\mine\programming\anaconda3\envs\ai\lib\site-packages (from scikit-image>=0.16.1->albumentations[imgaug]) (23.1)
# Requirement already satisfied: lazy_loader>=0.2 in c:\users\genih\appdata\roaming\python\python38\site-packages (from scikit-image>=0.16.1->albumentations[imgaug]) (0.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\genih\appdata\roaming\python\python38\site-packages (from scikit-learn>=0.19.1->qudida>=0.0.4->albumentations[imgaug]) (3.1.0)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\genih\appdata\roaming\python\python38\site-packages (from scikit-learn>=0.19.1->qudida>=0.0.4->albumentations[imgaug]) (1.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\genih\appdata\roaming\python\python38\site-packages (from matplotlib->imgaug>=0.4.0->albumentations[imgaug]) (1.0.7)
# Requirement already satisfied: python-dateutil>=2.7 in c:\mine\programming\anaconda3\envs\ai\lib\site-packages (from matplotlib->imgaug>=0.4.0->albumentations[imgaug]) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\genih\appdata\roaming\python\python38\site-packages (from matplotlib->imgaug>=0.4.0->albumentations[imgaug]) (0.11.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\mine\programming\anaconda3\envs\ai\lib\site-packages (from matplotlib->imgaug>=0.4.0->albumentations[imgaug]) (5.12.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\genih\appdata\roaming\python\python38\site-packages (from matplotlib->imgaug>=0.4.0->albumentations[imgaug]) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\genih\appdata\roaming\python\python38\site-packages (from matplotlib->imgaug>=0.4.0->albumentations[imgaug]) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\genih\appdata\roaming\python\python38\site-packages (from matplotlib->imgaug>=0.4.0->albumentations[imgaug]) (4.39.4)
# Requirement already satisfied: zipp>=3.1.0 in c:\mine\programming\anaconda3\envs\ai\lib\site-packages (from importlib-resources>=3.2.0->matplotlib->imgaug>=0.4.0->albumentations[imgaug]) (3.15.0)

# %%
# Create a random multiple transformation pipeline
transform = A.Compose([
    A.RandomRotate90(),
    A.Flip(),
    A.Transpose(),  # Swap rows and columns
    A.OneOf([
        A.IAAAdditiveGaussianNoise(),  # Apply Additive Gaussian Noise to image using 'imgaug' library
        A.GaussNoise(), # Apply Gaussian Noise to image using 'albumentations' library
    ], p=0.2),  # a chance of 20% 
    A.OneOf([
        A.MotionBlur(p=0.2),
        A.MedianBlur(blur_limit=3, p=0.1),
        A.Blur(blur_limit=3, p=0.1)
    ], p=0.2),
    A.ShiftScaleRotate(shift_limit=0.0625,  # Max proportion to be shifted horizontally or vertically -> '0.0625': shifted up to 6.25% 
                      scale_limit=0.2,      # Max proportion to be scaled up or down -> '0.2': scaled up to 20%
                      rotate_limit=45,      # Max angle to be rotated clockwise or counterclockwise -> '45': rotated up to degree of 45
                      p=0.2),
    A.OneOf([
        A.OpticalDistortion(p=0.3),  # Create a fisheye or barrel distortion effect
        A.GridDistortion(p=0.1),     # Create stretching or compressing effects
        A.IAAPiecewiseAffine(p=0.3)  # Create localized distortions and deformations
    ], p=0.2),
    A.OneOf([
        A.CLAHE(clip_limit=2), # CLAHE(Applies Contrast Limited Adaptive Histogram Equalization): Enhance image contrast
        A.IAASharpen(),  # Enhance edges and details using IAAShapen
        A.IAAEmboss(),   # Create a relief-like texture by emphasizing high-frequency components
        A.RandomBrightnessContrast()
    ], p=0.3),
    A.HueSaturationValue(p=0.3)
])

image_adjusted = transform(image = image)['image']

# Visualization
visualization(image, 'Original Image')
visualization(image_adjusted, 'Adjusted Image: Multiple Transformation with random options')
