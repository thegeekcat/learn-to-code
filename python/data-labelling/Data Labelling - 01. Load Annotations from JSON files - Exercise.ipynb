# %%
# Import modules
import json
import os
import cv2
import matplotlib.pyplot as plt

# %%
# Set a path
json_data_path = './data/cat_dog_rabbit_annotation_json.json'

# Load JSON
with open(json_data_path, 'r', encoding='utf-8') as j:
    json_data = json.load(j)
    
print(json_data)
# Out:
# {'licenses': [{'name': '', 'id': 0, 'url': ''}], 'info': {'contributor': '', 'date_created': '', 'description': '', 'url': '', 'version': '', 'year': ''}, 'categories': [{'id': 1, 'name': 'cat', 'supercategory': ''}, {'id': 2, 'name': 'dog', 'supercategory': ''}, {'id': 3, 'name': 'rabbit', 'supercategory': ''}, {'id': 4, 'name': 'guinea pig', 'supercategory': ''}], 'images': [{'id': 1, 'width': 484, 'height': 277, 'file_name': 'cat_dog_rabbit.PNG', 'license': 0, 'flickr_url': '', 'coco_url': '', 'date_captured': 0}], 'annotations': [{'id': 1, 'image_id': 1, 'category_id': 1, 'segmentation': [[282.0, 66.0, 278.0, 66.0, 267.0, 76.0, 258.0, 78.0, 230.0, 78.0, 224.0, 76.0, 211.0, 66.0, 207.0, 68.0, 206.0, 110.0, 211.0, 130.0, 216.0, 135.0, 210.0, 139.0, 212.0, 145.0, 208.0, 149.0, 203.0, 171.0, 204.0, 174.0, 198.0, 182.0, 198.0, 196.0, 195.0, 204.0, 198.0, 210.0, 198.0, 220.0, 210.0, 226.0, 213.0, 239.0, 220.0, 241.0, 224.0, 248.0, 240.0, 249.0, 248.0, 247.0, 250.0, 249.0, 251.0, 247.0, 250.0, 250.0, 254.0, 255.0, 279.0, 254.0, 277.0, 254.0, 277.0, 249.0, 279.0, 248.0, 281.0, 237.0, 285.0, 240.0, 298.0, 240.0, 300.0, 235.0, 299.0, 222.0, 294.0, 212.0, 294.0, 201.0, 299.0, 176.0, 303.0, 174.0, 299.84, 149.79, 284.0, 121.0, 285.0, 104.0, 283.0, 100.0, 283.0, 86.0, 285.0, 74.0]], 'area': 15209.0, 'bbox': [195.0, 66.0, 108.0, 189.0], 'iscrowd': 0, 'attributes': {'occluded': False}}, {'id': 2, 'image_id': 1, 'category_id': 2, 'segmentation': [[156.0, 43.0, 145.0, 43.0, 137.0, 38.0, 121.0, 34.0, 105.0, 35.0, 98.0, 38.0, 89.0, 35.0, 82.0, 39.0, 56.0, 46.0, 45.0, 54.0, 47.0, 74.0, 57.0, 100.0, 58.0, 108.0, 62.0, 110.0, 74.0, 97.0, 72.0, 101.0, 81.0, 116.0, 77.0, 118.0, 75.0, 127.0, 64.0, 141.0, 59.0, 166.0, 52.0, 175.0, 40.0, 185.0, 37.0, 183.0, 27.0, 185.0, 14.0, 195.0, 16.0, 208.0, 18.0, 207.0, 22.0, 211.0, 29.0, 211.0, 29.0, 217.0, 31.0, 219.0, 30.0, 230.0, 32.0, 232.0, 29.0, 237.0, 28.0, 246.0, 34.0, 252.0, 47.0, 254.0, 71.0, 252.0, 73.0, 247.0, 68.0, 215.0, 74.0, 212.0, 71.0, 215.0, 84.0, 224.0, 101.0, 228.0, 96.0, 
0], 'iscrowd': 0, 'attributes': {'occluded': False}}, {'id': 3, 'image_id': 1, 'category_id': 3, 'segmentation': [[360.0, 112.0, 362.0, 120.0, 361.0, 152.0, 364.0, 157.0, 363.0, 159.0, 372.0, 167.0, 385.0, 184.0, 384.0, 195.0, 377.0, 204.0, 377.0, 210.0, 375.0, 212.0, 382.0, 225.0, 382.0, 234.0, 376.0, 239.0, 377.0, 241.0, 370.0, 240.0, 367.0, 245.0, 356.0, 253.0, 343.0, 253.0, 340.0, 251.0, 342.0, 247.0, 338.0, 243.0, 333.0, 243.0, 326.0, 239.0, 325.0, 245.0, 322.0, 247.0, 324.0, 250.0, 320.0, 254.0, 309.0, 254.0, 302.0, 247.0, 303.0, 240.0, 299.0, 234.0, 299.0, 222.0, 294.0, 212.0, 294.0, 201.0, 299.0, 177.0, 305.0, 173.0, 306.0, 169.0, 312.0, 163.0, 310.0, 158.0, 314.0, 154.0, 312.0, 150.0, 314.0, 111.0, 333.0, 133.0, 340.0, 131.0, 347.0, 132.0, 347.0, 128.0]], 'area': 8771.0, 'bbox': [294.0, 111.0, 91.0, 143.0], 'iscrowd': 0, 'attributes': {'occluded': False}}, {'id': 4, 'image_id': 1, 'category_id': 4, 'segmentation': [[434.0, 159.0, 430.0, 162.0, 427.0, 161.0, 417.0, 165.0, 412.0, 163.0, 403.0, 178.0, 395.0, 186.0, 387.0, 190.0, 377.0, 204.0, 375.0, 213.0, 382.0, 225.0, 382.0, 234.0, 388.0, 246.0, 398.0, 254.0, 434.0, 254.0, 442.0, 251.0, 457.0, 238.0, 466.0, 237.0, 475.0, 226.0, 476.0, 217.0, 469.0, 197.0, 469.0, 191.0, 465.0, 186.0, 439.0, 168.0]], 'area': 6672.0, 'bbox': [375.0, 159.0, 101.0, 95.0], 'iscrowd': 0, 'attributes': {'occluded': False}}]

# %%
# Set labels
label_dict = {1: 'cat',
              2: 'dog',
              3: 'rabbit',
              4: 'guinea pig'}

# %%
# Get image info
for image_json in images_info:
    
    # Get details
    image_id = image_json['id']
    file_name = image_json['file_name']
    image_width = image_json['width']
    image_height = image_json['height']
    #print(image_id, file_name, image_width, image_height)
    
    # Read images
    image_path = os.path.join('./data/', file_name)
    #print(image_path)
    image = cv2.imread(image_path)
    #print(image)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    
    # Get bounding boxes
    for anno_json in annotations_info:
        if image_id == anno_json['image_id']:
            #################
            # Get positions of bounding boxes
            bbox = anno_json['bbox']  # x, y, w, h
            x = int(bbox[0])
            y = int(bbox[1])
            w = int(bbox[2])
            h = int(bbox[3])
            #print(x, y, w, h)
            
            # Draw rectangles
            cv2.rectangle(image, (x, y), (x+w, y+h), (205, 0, 0), 1)
            
            #################
            # Display labels
            category_id = anno_json['category_id']
            #print(category_id)
            
            # Get label names
            label_name = label_dict[category_id]
            #print(label_name)
            
            # Display labels
            image = cv2.putText(image, label_name, (x, y-5), cv2.FONT_HERSHEY_PLAIN, 1, (0, 0, 255), 1, cv2.LINE_AA)
    plt.imshow(image)
    plt.show()
